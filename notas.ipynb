# %% [markdown]
# # FLASK
#
#
# Flask es un framework de Python usado para desarrollar aplicaciones pequeñas... en primera instancia no posee varias características que podría tener un  framework mas completo... pero conforme se vayan utilizando se le pueden ir agregando funcionalidades
#
# ## Características
#
# 1. Usa Jinga 2 (Template Engine)
# 2. Es lightweight
# 3. No tiene ORM de forma directa...
#
#
# ## ¿Cómo funciona el request de una aplicación web?
#
# Básicamente la computadora manda una petición al servidor este la lee y consulta en la base de datos por la información que se solicite... luego se trabaja esta información y se le entrega al servidor la cual devuelve con un response al navegador del usuario el cual renderiza la información HTML enviada por el servidor
#
#
# ## Variables de entorno
#
# FLASK_APP=main.py
# FLASK_DEBUG=
#
#
# ## TEMPLATES
#
# ### ¿Para que sirven?
#
# Usando Jinja2 podemos generar HTML estatico o dinamico lo cual nos permitirá bastante libertad y nos permitira regresar HTML en vez de un string...
#
# Flask esta configurado para buscar en un directorio llamado  **templates ***
#
#
# ### Estructuras de Control
#
# SINTAXIS IF :
#
#     {% if variable %}
#         <h1> Ejemplo </h1>
#     {% else %}
#         <h2> Ejemplo 2</>
#
#     {% endif %}
#
# SINTAXIS EXTENDER:
#     {%extends 'nombre_archivo.html' %}
# * Sirve para tener un HTML base al cual modificaremos...
#
#
# SINTAXIS "BLOQUE" :
#
#     {% block title %}
#
#     {{super()}}
#     Bienvenido
#
#     {% end block %}
#
#     {% block content %}
#
#
#     {% end block %}
#
# ## Herencia de templates
#
# ### ¿Que hace?
#
# Extiende la base de un html y colocando las estructuras de control podemos modificar solo partes exclusivas del template
#
# ### Sintaxis 1 extends y  2 super  3 insertar archivo html en index.html
#
# 1. Colocar {% extends 'archivo_html.html%}
#
# 2. {%block title%}
#         {{super()}}
#         Bienvenido
#     {% endblock %}
#
# 3. {{ %include 'nombre_archivo.html%}}
#
# ## Uso de archivos estaticos: imágenes
#
# ### Pasos
#
# 1. Crear Carpeta /static
# 2. Crear /static/images
# 3. usar <img src="{{url_for('static', filename='images/Evaluador General.png')}}">
# 4. Para css /static/css
#
#
# ## Codigos de error
#
# Códigos de error:
#
# ### 100
# 100: no son errores sino mensajes informativos. Como usuario nunca los verás, sino que entre bambalinas indica que la petición se ha recibido y se continúa el proceso.
#
# ### 200
# 200: estos códigos también indican que todo ha ido correctamente. La petición se ha recibido, se ha procesado y se ha devuelto satisfactoriamente. Por tanto, nunca los verás en tu navegador, pues significan que todo ha ido bien.
#
# ### 300
#
# 300: están relacionados con redirecciones. Los servidores usan estos códigos para indicar al navegador que la página o recurso que han pedido se ha movido de sitio. Como usuario, no verás estos códigos, aunque gracias a ellos una página te podría redirigir automáticamente a otra.
#
# ### 400
# 400: corresponden a errores del cliente y con frecuencia sí los verás. Es el caso del conocido error 404, que aparece cuando la página que has intentado buscar no existe. Es, por tanto, un error del cliente (la dirección web estaba mal).
#
# ### 500
# 500: mientras que los códigos de estado 400 implican errores por parte del cliente (es decir, de parte tuya, tu navegador o tu conexión), los errores 500 son errores desde la parte del servidor. Es posible que el servidor tenga algún problema temporal y no hay mucho que puedas hacer salvo probar de nuevo más tarde.
#
# ### Manejo de errores
#
# @app.errorhandler(404)
#
# def not_found(error):
#     return render_template('404.html',error=error)
#
#
# ## Uso de Bootstrap-Flask
#
# pip install bootstrap-flask
#
#
# en main.py:
#
# bootstrap= Bootstrap(app) # se crea instancia que permite usarlo
#
#  ### "Content Delivery Network"
#
#  <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap/5.0.0/css/bootstrap.min.css">
